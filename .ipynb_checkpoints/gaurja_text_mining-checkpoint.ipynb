# %%
import pandas as pd 
import re

# %%
import nltk
from nltk.corpus import stopwords

# %%
data_dir = "Text-Mining-main/data/NYT_article_data.csv"
df = pd.read_csv(data_dir)

# %%
print(df.columns)
reviews = list(df["snippet"])
print(reviews[:3])
# Out:
# Index(['web_url', 'headline', 'snippet', 'word_count', 'source',
#        'type_of_material', 'date', 'id'],
#       dtype='object')
# ['Nick Kyrgios started his Brisbane Open title defense with a battling 7-6(5) 5-7 7-6(5) victory over American Ryan Harrison in the opening round on Tuesday.', "British police confirmed on Tuesday they were treating a stabbing attack which injured three people at Manchester's Victoria train station as a terrorist investigation, and were searching an address in the Cheetham Hill area of the city.", 'Marcellus Wiley is still on the fence about letting his young son play football. But the former NFL defensive end and Fox Sports personality tells PodcastOne Sports Now that he likes what the NFL is doing to try and make football a safer game, des...']

# %%
nltk.download("stopwords")
stopwords_list = stopwords.words("english")
print(stopwords_list[:5])
# Out:
# ['i', 'me', 'my', 'myself', 'we']
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\91987\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
a = [ 
    [
    word 
    for word in (re.sub("[^a-zA-Z]", " ",text.lower())).split()
    if not word in stopwords_list
        
    ]
    for text in reviews
    
]
print(a)
# Out:
# [['nick', 'kyrgios', 'started', 'brisbane', 'open', 'title', 'defense', 'battling', 'victory', 'american', 'ryan', 'harrison', 'opening', 'round', 'tuesday'], ['british', 'police', 'confirmed', 'tuesday', 'treating', 'stabbing', 'attack', 'injured', 'three', 'people', 'manchester', 'victoria', 'train', 'station', 'terrorist', 'investigation', 'searching', 'address', 'cheetham', 'hill', 'area', 'city'], ['marcellus', 'wiley', 'still', 'fence', 'letting', 'young', 'son', 'play', 'football', 'former', 'nfl', 'defensive', 'end', 'fox', 'sports', 'personality', 'tells', 'podcastone', 'sports', 'likes', 'nfl', 'try', 'make', 'football', 'safer', 'game', 'des'], ['still', 'reckoning', 'fallout', 'emmett', 'till', 'painting', 'chastened', 'artist', 'reveals', 'controversy', 'changed', 'even', 'moves', 'forward', 'new', 'gallery', 'show'], ['far', 'arike', 'ogunbowale', 'coach', 'muffet', 'mcgraw', 'concerned', 'notre', 'dame', 'victory', 'louisville', 'thursday', 'night', 'another', 'atlantic', 'coast', 'conference', 'game', 'january'], ['prohibition', 'whole', 'home', 'vacation', 'rentals', 'arranged', 'online', 'airbnb', 'moved', 'closer', 'reality', 'thursday', 'new', 'orleans'], ['contaminated', 'food', 'smell', 'like', 'freedom'], ['end', 'sight', 'partial', 'federal', 'shutdown', 'distressing', 'federal', 'workers', 'paycheck', 'sight', 'either'], ['bottlenecks', 'offloading', 'imported', 'fuel', 'forming', 'mexican', 'oil', 'ports', 'following', 'government', 'orders', 'shut', 'pipelines', 'limit', 'losses', 'widespread', 'fuel', 'theft', 'according', 'traders', 'refinitiv', 'eikon', 'data'], ['following', 'reaction', 'andy', 'murray', 'announcement', 'friday', 'year', 'australian', 'open', 'could', 'last', 'tournament', 'professional'], ['labor', 'movement', 'pressing', 'government', 'get', 'federal', 'employees', 'back', 'work', 'highlighting', 'ways', 'basic', 'services', 'could', 'compromised'], ['house', 'democrats', 'left', 'classified', 'briefing', 'treasury', 'secretary', 'skeptical', 'plan', 'unimpressed', 'secretary', 'defense'], ['police', 'accused', 'spanish', 'tennis', 'player', 'marc', 'fornell', 'mestres', 'link', 'players', 'armenian', 'ring', 'bribed', 'betting', 'purposes'], ['taiwanese', 'president', 'tsai', 'ing', 'wen', 'appointed', 'close', 'political', 'ally', 'premier', 'cabinet', 'reshuffle', 'friday', 'following', 'ruling', 'party', 'heavy', 'election', 'losses', 'growing', 'pressure', 'rival', 'china'], ['fulham', 'looking', 'sign', 'experienced', 'leaders', 'january', 'transfer', 'window', 'help', 'struggling', 'club', 'retain', 'premier', 'league', 'status', 'manager', 'claudio', 'ranieri', 'said'], ['williams', 'seeded', 'th', 'may', 'fourth', 'round', 'match', 'top', 'seeded', 'simona', 'halep', 'perhaps', 'sister', 'venus', 'melbourne'], ['police', 'offered', 'motive', 'alleged', 'actions', 'year', 'old', 'man', 'appeared', 'court', 'thursday', 'charges', 'could', 'carry', 'year', 'prison', 'sentence'], ['mostly', 'quiet', 'third', 'period', 'nearly', 'cost', 'new', 'york', 'islanders', 'took', 'one', 'shot', 'josh', 'bailey', 'make'], ['federal', 'jury', 'found', 'suburban', 'north', 'texas', 'couple', 'guilty', 'enslaving', 'guinean', 'woman', 'years'], ['work', 'public', 'art', 'neighborhood', 'elsewhere', 'makes', 'smile', 'grimace', 'scratch', 'head', 'like', 'know'], ['epiphany', 'celebrations', 'bring', 'together', 'hundreds', 'people', 'romanian', 'village', 'pietrosani', 'day', 'freezing', 'temperatures', 'culminates', 'bareback', 'horse', 'race', 'across', 'muddy', 'frozen', 'snowy', 'fields'], ['daily', 'look', 'late', 'breaking', 'news', 'upcoming', 'events', 'stories', 'talked', 'today'], ['indian', 'police', 'friday', 'said', 'investigating', 'academic', 'journalist', 'peasant', 'leader', 'possible', 'sedition', 'publicly', 'opposing', 'proposal', 'grant', 'citizenship', 'non', 'muslims', 'neighboring', 'muslim', 'majority', 'countries'], ['politics', 'newsletter', 'need', 'throw',  ...
